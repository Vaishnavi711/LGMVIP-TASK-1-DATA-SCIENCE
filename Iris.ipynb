# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **NAME-DEVKATE VAISHNAVI YOGESH**
#
# **INTERSHIP-LETSGROWMORE (LGM VIP NOVEMBER)**
#
# **DOMAIN-DATA SCIENCE**
#
# **TASK NO-1(IRIS FLOWER CLASSIFICATION ML PROJECT)**

# %% [markdown]
# The Aim of this project is to divide iris flower into three categories(setosa,versicolour,virginica)

# %% [markdown]
# **IMPORT** **LIBRARIES**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url='https://raw.githubusercontent.com/jbrownlee/Datasets/master/iris.csv'

# %%
col_name=['Sepal Length','Sepal Width','Petal Length','Petal Width','Class']

# %%
dataset=pd.read_csv(url, names=col_name)

# %%
dataset
# Out:
#      Sepal Length  Sepal Width  Petal Length  Petal Width           Class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# **DATA** **FORMATION**

# %%
dataset.shape
# Out:
# (150, 5)

# %%
dataset.size
# Out:
# 750

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Sepal Length  150 non-null    float64
#  1   Sepal Width   150 non-null    float64
#  2   Petal Length  150 non-null    float64
#  3   Petal Width   150 non-null    float64
#  4   Class         150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
dataset.head()
# Out:
#    Sepal Length  Sepal Width  Petal Length  Petal Width        Class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
dataset.tail()
# Out:
#      Sepal Length  Sepal Width  Petal Length  Petal Width           Class
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica

# %%
dataset.describe()
# Out:
#        Sepal Length  Sepal Width  Petal Length  Petal Width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# **DATA** **VISUALISATION**

# %% [markdown]
# **PAIR PLOT**

# %%
sns.set_theme(style="ticks", palette="pastel")
sns.pairplot(dataset, hue='Class', markers=["1","2","3"], palette=["r","g","b"] )
plt.show()

# %% [markdown]
# **Box** **Plot**

# %%
sns.set_theme(style="whitegrid", palette="pastel")
sns.boxplot(x="Class", y="Sepal Length",
            hue="Class", palette=["b","g","r"],
            data=dataset)
sns.despine(offset=10, trim=True)

# %% [markdown]
# **JOINT** **PLOT**

# %%
sns.set_theme(style="whitegrid", palette="pastel")
g = sns.jointplot(data=dataset, x="Petal Length", y="Petal Width", hue="Class", kind="kde", palette=["b","g","r"])

# %% [markdown]
# **VIOLIN** **PLOT**

# %%
sns.set_theme(style="whitegrid", palette="pastel")
sns.violinplot(y='Class', x='Sepal Length', data=dataset, inner='quartile', palette=["b","g","r"])
plt.show()
sns.violinplot(y='Class', x='Sepal Width', data=dataset, inner='quartile', palette=["b","g","r"])
plt.show()
sns.violinplot(y='Class', x='Petal Length', data=dataset, inner='quartile', palette=["b","g","r"])
plt.show()
sns.violinplot(y='Class', x='Petal Width', data=dataset, inner='quartile', palette=["b","g","r"])
plt.show()

# %% [markdown]
# **TRAIN TEST SPLIT MODEL**

# %%
from sklearn.model_selection import train_test_split
X = dataset.drop(['Class'], axis=1)
y = dataset['Class']
from sklearn.preprocessing import StandardScaler
X = StandardScaler().fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %% [markdown]
# **MACHINE LEARNING** **(LOGISTIC REGRESSION ALGORITHM)**

# %%
from sklearn.linear_model import LogisticRegression
log_reg = LogisticRegression()
log_reg.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
log_reg.score(X_train, y_train)
# Out:
# 0.9732142857142857

# %%
log_reg.score(X, y)
# Out:
# 0.96

# %%
log_reg.score(X_test, y_test)
# Out:
# 0.9210526315789473

# %% [markdown]
# **ACCURACY OF** **MODEL**

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.svm import SVC
model = SVC(gamma='auto')
model.fit(X_train, y_train)
prediction = model.predict(X_test)
print(f'Accuracy of Model: {accuracy_score(y_test, prediction)}')
print(f'Report of Model: \n {classification_report(y_test, prediction)}')
# Out:
# Accuracy of Model: 0.9473684210526315
# Report of Model:
#                   precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00         9
# Iris-versicolor       0.93      0.93      0.93        15
#  Iris-virginica       0.93      0.93      0.93        14
#
#        accuracy                           0.95        38
#       macro avg       0.95      0.95      0.95        38
#    weighted avg       0.95      0.95      0.95        38

# %% [markdown]
# **THANK YOU!!!**
